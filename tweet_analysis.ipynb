# %%
import re
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

import datetime as dt
from collections import Counter

import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import word_tokenize
from nltk.corpus import words
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
#for kamala analysis use /content/tweet_trump.csv
#for trump analysis use /content/tweet_kamala.csv
df = pd.read_csv('/content/tweet_trump.csv')

# %%
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1833973370460815785  Wed Sep 11 20:58:19 +0000 2024             288
# 1  1840195818198052940  Sun Sep 29 01:04:06 +0000 2024             345
# 2  1836786753765519766  Thu Sep 19 15:17:42 +0000 2024            4464
# 3  1850662507481792623  Sun Oct 27 22:15:26 +0000 2024             723
# 4  1847203688097407237  Fri Oct 18 09:10:53 +0000 2024             494
#
#                                            full_text               id_str  \
# 0  TRUMP 2024 🇺🇸🇺🇸 @LadyConstance8 @NancyMar2022 ...  1833973370460815785
# 1  ⭐️ The 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘴𝘱𝘪𝘳𝘪𝘵 𝘪𝘴 𝙂𝙍𝙀𝘼𝙏! ⭐️ 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘤...  1840195818198052940
# 2  Recent Poll shows Donald Trump WINNING IN A LA...  1836786753765519766
# 3  @realDonaldTrump With Trump in 2024? Here s a ...  1850662617917858188
# 4  NOW more than EVER MAGA 🇺🇸 TRUMP 2024 https://...  1847203688097407237
#
#                                            image_url in_reply_to_screen_name  \
# 0    https://pbs.twimg.com/media/GXOVD0cXYAAl3D_.jpg                     NaN
# 1  https://pbs.twimg.com/amplify_video_thumb/1840...                     NaN
# 2    https://pbs.twimg.com/media/GX2TzpvX0AADuiW.jpg                     NaN
# 3    https://pbs.twimg.com/media/Ga7f13qWcAEgvoP.jpg         realDonaldTrump
# 4    https://pbs.twimg.com/media/GaKV9p7XgAAaeJF.jpg                     NaN
#
#   lang               location  quote_count  reply_count  retweet_count  \
# 0   en                    NaN            6           47            168
# 1   en  The Great Lakes State            4            6            238
# 2   en                India🇮🇳           44         1218            816
# 3   en                    NaN            4           67             97
# 4   en                    NaN            1           25            212
#
#                                            tweet_url          user_id_str  \
# 0  https://x.com/Langer424/status/183397337046081...  1521692036897902592
# 1  https://x.com/1776Diva/status/1840195818198052940  1343367645748473856
# 2  https://x.com/SUBRATA30016572/status/183678675...  1142736007567069184
# 3  https://x.com/TuckerCarlsonHQ/status/185066261...  1755191109574107136
# 4  https://x.com/DameScorpio/status/1847203688097...  1551523351843192834
#
#           username
# 0        Langer424
# 1         1776Diva
# 2  SUBRATA30016572
# 3  TuckerCarlsonHQ
# 4      DameScorpio

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      545 non-null    int64
#  1   created_at               545 non-null    object
#  2   favorite_count           545 non-null    int64
#  3   full_text                545 non-null    object
#  4   id_str                   545 non-null    int64
#  5   image_url                389 non-null    object
#  6   in_reply_to_screen_name  46 non-null     object
#  7   lang                     545 non-null    object
#  8   location                 386 non-null    object
#  9   quote_count              545 non-null    int64
#  10  reply_count              545 non-null    int64
#  11  retweet_count            545 non-null    int64
#  12  tweet_url                545 non-null    object
#  13  user_id_str              545 non-null    int64
#  14  username                 545 non-null    object
# dtypes: int64(7), object(8)
# memory usage: 64.0+ KB

# %% [markdown]
# **Data Processing**

# %%
df['created_at'] = df['created_at'].apply(lambda x: dt.datetime.strptime(x, '%a %b %d %H:%M:%S %z %Y'))

# %%
df.dtypes
# Out:
# conversation_id_str                      int64
# created_at                 datetime64[ns, UTC]
# favorite_count                           int64
# full_text                               object
# id_str                                   int64
# image_url                               object
# in_reply_to_screen_name                 object
# lang                                    object
# location                                object
# quote_count                              int64
# reply_count                              int64
# retweet_count                            int64
# tweet_url                               object
# user_id_str                              int64
# username                                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# conversation_id_str          0
# created_at                   0
# favorite_count               0
# full_text                    0
# id_str                       0
# image_url                  156
# in_reply_to_screen_name    499
# lang                         0
# location                   159
# quote_count                  0
# reply_count                  0
# retweet_count                0
# tweet_url                    0
# user_id_str                  0
# username                     0
# dtype: int64

# %%
df['location'].nunique()
# Out:
# 199

# %% [markdown]
# **Removing Duplicates**

# %%
tweets_list = df['full_text'].tolist()
len(tweets_list)
# Out:
# 545

# %%
tweets_list_updated = set(tweets_list)
len(tweets_list_updated)
# Out:
# 490

# %%
df['full_text'].duplicated().sum()
# Out:
# 55

# %%
df = df.drop_duplicates(subset = 'full_text', keep = 'first',ignore_index = True)
df.shape
# Out:
# (490, 15)

# %% [markdown]
# **Removing Emojis**

# %%
import re

def remove_emoji(full_text):
    emoji_pattern = re.compile("["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags=re.UNICODE)
    # Changed 'tweet' to 'full_text' to use the correct column name
    return emoji_pattern.sub(r'', full_text)

# Changed 'Tweet' to 'full_text' to apply the function to the correct column
df['Processed_Tweet'] = df['full_text'].apply(remove_emoji)
# Out:
# <ipython-input-235-f20a2cc0c35c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Processed_Tweet'] = df['full_text'].apply(remove_emoji)

# %%
count = 0
for i in df['Processed_Tweet']:
    if re.match(r'^RT', i):  #remove any rows that contain RT
        df.drop(df.loc[df['Processed_Tweet']==i].index,inplace = True)
        count+=1

count
# Out:
# 0

# %%
df.shape
# Out:
# (490, 16)

# %%
df['Processed_Tweet']
# Out:
# 0      TRUMP 2024  @LadyConstance8 @NancyMar2022 @cal...
# 1      ⭐️ The 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘴𝘱𝘪𝘳𝘪𝘵 𝘪𝘴 𝙂𝙍𝙀𝘼𝙏! ⭐️ 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘤...
# 2      Recent Poll shows Donald Trump WINNING IN A LA...
# 3      @realDonaldTrump With Trump in 2024? Here s a ...
# 4      NOW more than EVER MAGA  TRUMP 2024 https://t....
#                              ...
# 485    Note from WNEP: Test results for the upcoming ...
# 486    .@Polymarket - 2024 Presidential Election Winn...
# 487    .@Polymarket - 2024 Presidential Election Winn...
# 488    #Detroit | Kamala Harris and Donald Trump make...
# 489     impose real hardship on much of the country W...
# Name: Processed_Tweet, Length: 490, dtype: object

# %% [markdown]
# **Removing Emojis**

# %%
df['Processed_Tweet'] = [re.sub('^RT[\s]','',i) for i in df['Processed_Tweet']]
# Out:
# <ipython-input-238-3ff30c63b106>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Processed_Tweet'] = [re.sub('^RT[\s]','',i) for i in df['Processed_Tweet']]

# %%
df['Processed_Tweet']
# Out:
# 0      TRUMP 2024  @LadyConstance8 @NancyMar2022 @cal...
# 1      ⭐️ The 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘴𝘱𝘪𝘳𝘪𝘵 𝘪𝘴 𝙂𝙍𝙀𝘼𝙏! ⭐️ 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘤...
# 2      Recent Poll shows Donald Trump WINNING IN A LA...
# 3      @realDonaldTrump With Trump in 2024? Here s a ...
# 4      NOW more than EVER MAGA  TRUMP 2024 https://t....
#                              ...
# 485    Note from WNEP: Test results for the upcoming ...
# 486    .@Polymarket - 2024 Presidential Election Winn...
# 487    .@Polymarket - 2024 Presidential Election Winn...
# 488    #Detroit | Kamala Harris and Donald Trump make...
# 489     impose real hardship on much of the country W...
# Name: Processed_Tweet, Length: 490, dtype: object

# %% [markdown]
# **Removing URLs**

# %%
df['Processed_Tweet'] = [re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', i) for i in df['Processed_Tweet']]
# Out:
# <ipython-input-239-8fd12435704f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Processed_Tweet'] = [re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', i) for i in df['Processed_Tweet']]

# %%
df['Processed_Tweet']
# Out:
# 0      TRUMP 2024  @LadyConstance8 @NancyMar2022 @cal...
# 1      ⭐️ The 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘴𝘱𝘪𝘳𝘪𝘵 𝘪𝘴 𝙂𝙍𝙀𝘼𝙏! ⭐️ 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘤...
# 2      Recent Poll shows Donald Trump WINNING IN A LA...
# 3      @realDonaldTrump With Trump in 2024? Here s a ...
# 4                   NOW more than EVER MAGA  TRUMP 2024
#                              ...
# 485    Note from WNEP: Test results for the upcoming ...
# 486    .@Polymarket - 2024 Presidential Election Winn...
# 487    .@Polymarket - 2024 Presidential Election Winn...
# 488    #Detroit | Kamala Harris and Donald Trump make...
# 489     impose real hardship on much of the country W...
# Name: Processed_Tweet, Length: 490, dtype: object

# %% [markdown]
# **Removing #**

# %%
df['Processed_Tweet'] = [re.sub(r'#([^\s]+)', r'\1', i) for i in df['Processed_Tweet']]
# Out:
# <ipython-input-240-da755b21ad8f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Processed_Tweet'] = [re.sub(r'#([^\s]+)', r'\1', i) for i in df['Processed_Tweet']]

# %%
df['Processed_Tweet']
# Out:
# 0      TRUMP 2024  @LadyConstance8 @NancyMar2022 @cal...
# 1      ⭐️ The 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘴𝘱𝘪𝘳𝘪𝘵 𝘪𝘴 𝙂𝙍𝙀𝘼𝙏! ⭐️ 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘤...
# 2      Recent Poll shows Donald Trump WINNING IN A LA...
# 3      @realDonaldTrump With Trump in 2024? Here s a ...
# 4                   NOW more than EVER MAGA  TRUMP 2024
#                              ...
# 485    Note from WNEP: Test results for the upcoming ...
# 486    .@Polymarket - 2024 Presidential Election Winn...
# 487    .@Polymarket - 2024 Presidential Election Winn...
# 488    Detroit | Kamala Harris and Donald Trump make ...
# 489     impose real hardship on much of the country W...
# Name: Processed_Tweet, Length: 490, dtype: object

# %% [markdown]
# **Using preprocessor library**

# %%
# !pip install tweet-preprocessor
# Out:
# Requirement already satisfied: tweet-preprocessor in /usr/local/lib/python3.11/dist-packages (0.6.0)

# %%
import preprocessor as p

# %%
df['Processed_Tweet'] = [p.clean(i) for i in df['Processed_Tweet']]

# %%
df['Processed_Tweet']
# Out:
# 0                                                  TRUMP
# 1                                          The ! ! ! ! !
# 2      Recent Poll shows Donald Trump WINNING IN A LA...
# 3                  With Trump in ? Here s a follow-back!
# 4                          NOW more than EVER MAGA TRUMP
#                              ...
# 485    Note from WNEP: Test results for the upcoming ...
# 486    . - Presidential Election Winner: Donald Trump...
# 487    . - Presidential Election Winner: Donald Trump...
# 488    Detroit | Kamala Harris and Donald Trump make ...
# 489    impose real hardship on much of the country Wh...
# Name: Processed_Tweet, Length: 490, dtype: object

# %% [markdown]
# **Removing numbers, puntuations and special characters**

# %%
df.Processed_Tweet = df.Processed_Tweet.str.replace("[^a-zA-Z]", " ")

# %%
df["Processed_Tweet"]
# Out:
# 0                                                  TRUMP
# 1                                          The ! ! ! ! !
# 2      Recent Poll shows Donald Trump WINNING IN A LA...
# 3                  With Trump in ? Here s a follow-back!
# 4                          NOW more than EVER MAGA TRUMP
#                              ...
# 485    Note from WNEP: Test results for the upcoming ...
# 486    . - Presidential Election Winner: Donald Trump...
# 487    . - Presidential Election Winner: Donald Trump...
# 488    Detroit | Kamala Harris and Donald Trump make ...
# 489    impose real hardship on much of the country Wh...
# Name: Processed_Tweet, Length: 490, dtype: object

# %% [markdown]
# **Converting tweets into lowercase**

# %%
df.Processed_Tweet = [low.lower() for low in df.Processed_Tweet]

# %%
df["Processed_Tweet"]
# Out:
# 0                                                  trump
# 1                                          the ! ! ! ! !
# 2      recent poll shows donald trump winning in a la...
# 3                  with trump in ? here s a follow-back!
# 4                          now more than ever maga trump
#                              ...
# 485    note from wnep: test results for the upcoming ...
# 486    . - presidential election winner: donald trump...
# 487    . - presidential election winner: donald trump...
# 488    detroit | kamala harris and donald trump make ...
# 489    impose real hardship on much of the country wh...
# Name: Processed_Tweet, Length: 490, dtype: object

# %% [markdown]
# **Removing stop words**

# %%
# !pip install nltk # Install the NLTK library if not already installed.
import nltk
nltk.download('stopwords') # Download the 'stopwords' dataset.
from nltk.corpus import stopwords
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words('english'))
stop_words = list(stop_words)
print(stop_words)
# Out:
# ['who', 'them', 'what', "you'd", 'am', 'on', 'between', 'does', 's', "you're", 'haven', 'there', "hadn't", 'yours', 'been', 'has', 'didn', 'needn', 'an', 'him', 'off', 're', 'any', 'why', 'through', 'ourselves', 'by', 'and', 'until', 'only', 'are', 'the', 'ours', "needn't", "weren't", 'a', 'they', 'more', 'that', 've', 'out', 'my', 'now', 'yourselves', 'when', 'after', "it's", 'once', 'in', "wasn't", 'then', 'i', 'how', 'no', 'for', 'itself', 'did', 'will', 'such', 'as', 'same', 'y', 'hadn', 'about', "wouldn't", 'ma', 'don', 'aren', 'isn', 'yourself', 'having', 't', 'wouldn', 'too', "hasn't", 'we', 'where', "you've", "you'll", 'which', 'down', 'weren', 'theirs', "don't", 'have', 'against', 'own', 'nor', 'should', "haven't", 'again', 'it', 'all', 'further', 'd', 'this', 'so', 'up', "doesn't", 'if', "that'll", 'had', 'both', 'very', "couldn't", 'below', 'myself', 'our', 'to', 'just', 'with', 'be', 'under', 'other', 'before', 'o', 'me', 'do', 'll', 'm', 'those', 'wasn', 'shouldn', 'at', 'not', "shan't", 'doing', 'were', 'or', 'over', 'its', 'her', 'while', "aren't", 'himself', 'than', "shouldn't", "should've", 'mightn', 'themselves', 'during', "she's", 'their', 'whom', 'but', 'into', 'mustn', 'you', 'these', 'of', 'hers', 'most', "mustn't", 'hasn', "won't", 'from', 'he', 'doesn', 'ain', 'shan', "didn't", 'couldn', 'his', 'few', 'is', 'above', 'herself', 'being', 'she', 'because', 'can', 'was', 'each', "mightn't", 'won', 'some', 'your', 'here', "isn't"]

# %%
df['Processed_Tweet'] = df.Processed_Tweet.apply(lambda x: ' '.join(w for w in x.split() if w not in stop_words))

# %%
df['Processed_Tweet']
# Out:
# 0                                                  trump
# 1                                              ! ! ! ! !
# 2      recent poll shows donald trump winning landsli...
# 3                                   trump ? follow-back!
# 4                                        ever maga trump
#                              ...
# 485    note wnep: test results upcoming november gene...
# 486    . - presidential election winner: donald trump...
# 487    . - presidential election winner: donald trump...
# 488    detroit | kamala harris donald trump make fina...
# 489    impose real hardship much country voters care ...
# Name: Processed_Tweet, Length: 490, dtype: object

# %% [markdown]
# **Tokenization**

# %%
# !pip install nltk transformers
import nltk
from nltk.tokenize import word_tokenize
from transformers import AutoTokenizer

# Download necessary resources for NLTK if not already present
nltk.download('punkt')

#Choose a model checkpoint from huggingface and instantiate the tokenizer.
# Replace "bert-base-uncased" with the desired pre-trained model.
model_checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['Processed_Tweet'] = df['Processed_Tweet'].apply(lambda x: tokenizer.tokenize(x))

# %%
df['Processed_Tweet']
# Out:
# 0                                                [trump]
# 1                                        [!, !, !, !, !]
# 2      [recent, poll, shows, donald, trump, winning, ...
# 3                         [trump, ?, follow, -, back, !]
# 4                                [ever, mag, ##a, trump]
#                              ...
# 485    [note, w, ##ne, ##p, :, test, results, upcomin...
# 486    [., -, presidential, election, winner, :, dona...
# 487    [., -, presidential, election, winner, :, dona...
# 488    [detroit, |, kamal, ##a, harris, donald, trump...
# 489    [impose, real, hardship, much, country, voters...
# Name: Processed_Tweet, Length: 490, dtype: object

# %% [markdown]
# **Stemming**

# %%
def lemmatize_stemming(text):
    stemmer=PorterStemmer()
    return stemmer.stem(text)

# %%
df['Processed_Tweet'] = df['Processed_Tweet'].apply(lambda x: [lemmatize_stemming(i) for i in x])

# %%
df['Processed_Tweet']
# Out:
# 0                                                [trump]
# 1                                        [!, !, !, !, !]
# 2      [recent, poll, show, donald, trump, win, lands...
# 3                         [trump, ?, follow, -, back, !]
# 4                                [ever, mag, ##a, trump]
#                              ...
# 485    [note, w, ##ne, ##p, :, test, result, upcom, n...
# 486    [., -, presidenti, elect, winner, :, donald, t...
# 487    [., -, presidenti, elect, winner, :, donald, t...
# 488    [detroit, |, kamal, ##a, harri, donald, trump,...
# 489    [impos, real, hardship, much, countri, voter, ...
# Name: Processed_Tweet, Length: 490, dtype: object

# %%
df['Processed_Tweet'] = df.Processed_Tweet.apply(lambda x: [i for i in x if len(i)>2])

# %%
df
# Out:
#      conversation_id_str                created_at  favorite_count  \
# 0    1833973370460815785 2024-09-11 20:58:19+00:00             288
# 1    1840195818198052940 2024-09-29 01:04:06+00:00             345
# 2    1836786753765519766 2024-09-19 15:17:42+00:00            4464
# 3    1850662507481792623 2024-10-27 22:15:26+00:00             723
# 4    1847203688097407237 2024-10-18 09:10:53+00:00             494
# ..                   ...                       ...             ...
# 485  1851703707710136420 2024-10-30 19:12:21+00:00               2
# 486  1850666294829359390 2024-10-27 22:30:03+00:00             986
# 487  1851021689326645710 2024-10-28 22:02:15+00:00             641
# 488  1853166101871690034 2024-11-03 20:03:23+00:00               1
# 489  1851691970491539776 2024-10-30 18:25:43+00:00               0
#
#                                              full_text               id_str  \
# 0    TRUMP 2024 🇺🇸🇺🇸 @LadyConstance8 @NancyMar2022 ...  1833973370460815785
# 1    ⭐️ The 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘴𝘱𝘪𝘳𝘪𝘵 𝘪𝘴 𝙂𝙍𝙀𝘼𝙏! ⭐️ 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘤...  1840195818198052940
# 2    Recent Poll shows Donald Trump WINNING IN A LA...  1836786753765519766
# 3    @realDonaldTrump With Trump in 2024? Here s a ...  1850662617917858188
# 4    NOW more than EVER MAGA 🇺🇸 TRUMP 2024 https://...  1847203688097407237
# ..                                                 ...                  ...
# 485  Note from WNEP: Test results for the upcoming ...  1851703707710136420
# 486  .@Polymarket - 2024 Presidential Election Winn...  1850666294829359390
# 487  .@Polymarket - 2024 Presidential Election Winn...  1851021689326645710
# 488  #Detroit | Kamala Harris and Donald Trump make...  1853166101871690034
# 489   impose real hardship on much of the country W...  1851691970491539776
#
#                                              image_url  \
# 0      https://pbs.twimg.com/media/GXOVD0cXYAAl3D_.jpg
# 1    https://pbs.twimg.com/amplify_video_thumb/1840...
# 2      https://pbs.twimg.com/media/GX2TzpvX0AADuiW.jpg
# 3      https://pbs.twimg.com/media/Ga7f13qWcAEgvoP.jpg
# 4      https://pbs.twimg.com/media/GaKV9p7XgAAaeJF.jpg
# ..                                                 ...
# 485                                                NaN
# 486    https://pbs.twimg.com/media/Ga7jLxkXEAADgiL.jpg
# 487    https://pbs.twimg.com/media/GbAmanRWwAApiEg.jpg
# 488                                                NaN
# 489                                                NaN
#
#     in_reply_to_screen_name lang               location  quote_count  \
# 0                       NaN   en                    NaN            6
# 1                       NaN   en  The Great Lakes State            4
# 2                       NaN   en                India🇮🇳           44
# 3           realDonaldTrump   en                    NaN            4
# 4                       NaN   en                    NaN            1
# ..                      ...  ...                    ...          ...
# 485                     NaN   en        Atlanta & Miami            0
# 486                     NaN   en                    NaN           14
# 487                     NaN   en                    NaN            8
# 488                     NaN   en       Hyderabad, India            0
# 489                     NaN   en              Iowa, USA            0
#
#      reply_count  retweet_count  \
# 0             47            168
# 1              6            238
# 2           1218            816
# 3             67             97
# 4             25            212
# ..           ...            ...
# 485            0              0
# 486           64            162
# 487           54            128
# 488            0              1
# 489            0              0
#
#                                              tweet_url          user_id_str  \
# 0    https://x.com/Langer424/status/183397337046081...  1521692036897902592
# 1    https://x.com/1776Diva/status/1840195818198052940  1343367645748473856
# 2    https://x.com/SUBRATA30016572/status/183678675...  1142736007567069184
# 3    https://x.com/TuckerCarlsonHQ/status/185066261...  1755191109574107136
# 4    https://x.com/DameScorpio/status/1847203688097...  1551523351843192834
# ..                                                 ...                  ...
# 485  https://x.com/AllAllatlanta/status/18517037077...  1571173375099166727
# 486  https://x.com/Politics_Polls/status/1850666294...           1903105045
# 487  https://x.com/Politics_Polls/status/1851021689...           1903105045
# 488  https://x.com/DeccanChronicle/status/185316610...             19519947
# 489  https://x.com/OhmsLaw78/status/185169197049153...            126313550
#
#             username                                    Processed_Tweet
# 0          Langer424                                            [trump]
# 1           1776Diva                                                 []
# 2    SUBRATA30016572  [recent, poll, show, donald, trump, win, lands...
# 3    TuckerCarlsonHQ                              [trump, follow, back]
# 4        DameScorpio                            [ever, mag, ##a, trump]
# ..               ...                                                ...
# 485    AllAllatlanta  [note, ##ne, ##p, test, result, upcom, novemb,...
# 486   Politics_Polls  [presidenti, elect, winner, donald, trump, kam...
# 487   Politics_Polls  [presidenti, elect, winner, donald, trump, kam...
# 488  DeccanChronicle  [detroit, kamal, ##a, harri, donald, trump, ma...
# 489        OhmsLaw78  [impos, real, hardship, much, countri, voter, ...
#
# [490 rows x 16 columns]

# %%
texts = []
texts = df.Processed_Tweet.apply(lambda x: [i for i in x] )

# %%
all_words = []
for i in texts:
    all_words.append(" ".join(i))

# %%
text = []
for i in texts:
    for j in i:
        text.append(j)

# %%
len(text)
# Out:
# 9661

# %% [markdown]
# **Wordcloud**

# %%
# !pip install wordcloud
from wordcloud import WordCloud # Importing the WordCloud class from the wordcloud library.
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(' '.join(text))

# %%
plt.figure(figsize = (12, 12), facecolor="None")
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.title("WordCloud of Trump Tweets")
plt.show()

# %% [markdown]
# **Tweets Data Analysis**

# %%
df['username'].value_counts()
# Out:
# username
# Politics_Polls     24
# ElectionTime_      11
# DanScavino         10
# LauraLoomer         9
# aladdinumar         9
#                    ..
# MrDWindsorAndMe     1
# PONY_Official       1
# BackThebluecool     1
# RaffyPindaHouse     1
# OhmsLaw78           1
# Name: count, Length: 339, dtype: int64

# %%
days = df['created_at'].dt.day.tolist()

# %%
no_of_days = Counter(days)
no_of_days
# Out:
# Counter({11: 8,
#          29: 10,
#          19: 6,
#          27: 10,
#          18: 13,
#          16: 13,
#          2: 17,
#          30: 18,
#          3: 189,
#          22: 8,
#          9: 7,
#          28: 10,
#          31: 26,
#          10: 7,
#          17: 8,
#          14: 3,
#          13: 6,
#          1: 39,
#          24: 12,
#          6: 6,
#          25: 12,
#          20: 6,
#          21: 9,
#          15: 8,
#          23: 7,
#          7: 5,
#          26: 10,
#          8: 3,
#          4: 10,
#          5: 3,
#          12: 1})

# %%
import matplotlib.pyplot as plt
from datetime import datetime
from collections import defaultdict

# Example dictionary with daily data: Replace this with your actual data
no_of_days = Counter(days)


# Aggregate tweet counts by month
monthly_counts = defaultdict(int)
for date, count in no_of_days.items():
    # Extract the original date string from the 'created_at' column
    # (Assuming 'df' is your original DataFrame containing the 'created_at' column)
    original_date_str = df['created_at'].dt.strftime('%Y-%m-%d')[date]

    # Extract month and year (mm/yyyy format)
    month_year = datetime.strptime(original_date_str, "%Y-%m-%d").strftime("%m/%Y")
    monthly_counts[month_year] += count

# Sort months in chronological order
sorted_months = sorted(monthly_counts.keys(), key=lambda x: datetime.strptime(x, "%m/%Y"))

# Prepare x-axis labels and tweet counts
months = sorted_months
tweet_counts = [monthly_counts[month] for month in months]

# Create the bar chart
fig = plt.figure(figsize=(15, 7))
plt.bar(range(len(months)), tweet_counts, align='center', alpha=0.5, color='red')

# Set x-ticks to the formatted months
plt.xticks(range(len(months)), months)

# Set axis labels and title
plt.xlabel("Month (mm/yyyy)")
plt.ylabel("Count Of Tweets")
plt.title("Count Of Extracted Tweets Per Month")

# Show the plot
plt.show()

# %%
hours = df['created_at'].dt.hour.tolist()

# %%
no_of_hours = Counter(hours)
no_of_hours
# Out:
# Counter({20: 34,
#          1: 16,
#          15: 24,
#          22: 62,
#          9: 6,
#          0: 15,
#          11: 12,
#          16: 32,
#          12: 15,
#          18: 24,
#          21: 30,
#          4: 12,
#          8: 7,
#          13: 14,
#          2: 22,
#          17: 20,
#          19: 36,
#          23: 62,
#          6: 4,
#          3: 9,
#          5: 5,
#          14: 17,
#          7: 3,
#          10: 9})

# %%
import matplotlib.pyplot as plt
from datetime import datetime
from collections import defaultdict

# Aggregate tweet counts by day
daily_counts = defaultdict(int)  # Changed 'monthly_counts' to 'daily_counts'
for date, count in no_of_days.items():  # 'no_of_days' should already be a Counter object

    # Assuming all tweets are from the current year, you can change if necessary
    # date_str = datetime(2025, 3, date).strftime("%Y-%m-%d")
    date_str = df['created_at'][date].strftime("%Y-%m-%d")
    # Extract month and year (mm/yyyy format)
    # month_year = datetime.strptime(date_str, "%Y-%m-%d").strftime("%m/%Y")
    daily_counts[date_str] += count

# Sort months in chronological order
sorted_days = sorted(daily_counts.keys(), key=lambda x: datetime.strptime(x, "%Y-%m-%d"))

# Prepare x-axis labels and tweet counts
# months = sorted_months
days = sorted_days
tweet_counts = [daily_counts[day] for day in days]

# Create the bar chart
fig = plt.figure(figsize=(15, 7))
plt.bar(range(len(days)), tweet_counts, align='center', alpha=0.5, color='red')

# Set x-ticks to the formatted months
plt.xticks(range(len(days)), days, rotation=45, ha='right')  # Rotated x-axis labels for better visibility

# Set axis labels and title
plt.xlabel("Day (YYYY-MM-DD)")  # Changed label to "Day"
plt.ylabel("Count Of Tweets")
plt.title("Count Of Extracted Tweets Per Day")  # Changed title to "Per Day"

# Show the plot
plt.show()

# %% [markdown]
# **Sentiment Analysis**

# %%
from textblob import TextBlob

# %%
pol=[]
for Tweet in all_words:
    blob = TextBlob(Tweet)
    pol.append(blob.sentiment.polarity)

# %%
len(pol)
# Out:
# 490

# %%
len(text)
# Out:
# 9661

# %%
df['Processed_Tweet']
# Out:
# 0                                                [trump]
# 1                                                     []
# 2      [recent, poll, show, donald, trump, win, lands...
# 3                                  [trump, follow, back]
# 4                                [ever, mag, ##a, trump]
#                              ...
# 485    [note, ##ne, ##p, test, result, upcom, novemb,...
# 486    [presidenti, elect, winner, donald, trump, kam...
# 487    [presidenti, elect, winner, donald, trump, kam...
# 488    [detroit, kamal, ##a, harri, donald, trump, ma...
# 489    [impos, real, hardship, much, countri, voter, ...
# Name: Processed_Tweet, Length: 490, dtype: object

# %%
positive=0
negative=0
neutral=0
for i in pol:
    if i>0:
        positive+=1
    elif i<0:
        negative+=1
    else:
        neutral+=1
print("Positive Tweets:",positive)
print("Negative Tweets:",negative)
print("Neutral Tweets",neutral)
# Out:
# Positive Tweets: 349
# Negative Tweets: 23
# Neutral Tweets 118

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
sentiment_scores= []
for i in all_words:
    sentiment_scores.append([sid.polarity_scores(i)])

# %%
value = []
for i in sentiment_scores:
    for dict1 in i:
        value.append(list(dict1.values()))

# %%
sentimental_score_df = pd.DataFrame(data = value, columns = ['Negative','Neutral','Positive','Compound'])
sentimental_score_df
# Out:
#      Negative  Neutral  Positive  Compound
# 0       0.000    1.000     0.000    0.0000
# 1       0.000    0.000     0.000    0.0000
# 2       0.000    0.519     0.481    0.7579
# 3       0.000    1.000     0.000    0.0000
# 4       0.000    1.000     0.000    0.0000
# ..        ...      ...       ...       ...
# 485     0.000    0.906     0.094    0.4588
# 486     0.000    0.648     0.352    0.5859
# 487     0.000    0.648     0.352    0.5859
# 488     0.000    1.000     0.000    0.0000
# 489     0.054    0.871     0.075    0.2263
#
# [490 rows x 4 columns]

# %%
sentimental_score_df['val'] = sentimental_score_df['Compound'].apply(lambda x: 'Neutral' if x == 0 else ('Positive' if x > 0 else 'Negative'))
sentimental_score_df.head()
# Out:
#    Negative  Neutral  Positive  Compound       val
# 0       0.0    1.000     0.000    0.0000   Neutral
# 1       0.0    0.000     0.000    0.0000   Neutral
# 2       0.0    0.519     0.481    0.7579  Positive
# 3       0.0    1.000     0.000    0.0000   Neutral
# 4       0.0    1.000     0.000    0.0000   Neutral

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming sentimental_score_df has a column named 'val' representing sentiment
sent_count = sentimental_score_df['val'].value_counts().reset_index()
sent_count.columns = ['sentiment', 'count']  # Rename columns to match barplot arguments

# Create the barplot
ax = sns.barplot(y="count", x='sentiment', data=sent_count)

# Add count labels to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 10),
                textcoords='offset points')

plt.show()

# %%
filepath = r"/content/NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt"
emolex_df = pd.read_csv(filepath,  names=["word", "emotion", "association"], skiprows=45, sep='\t')
emolex_df.head(12)
len(emolex_df)
# Out:
# 141775

# %%
emotions={'positive':0, 'negative':0, 'surprise':0,'sadness':0,
          'anger':0,'joy':0,'negative':0,'trust':0,'fear':0,'anticipation':0,'disgust':0}

# %%
word_emotion=dict()
for i in range(0,86343):
    emotion=emolex_df['emotion'][i]
    word=emolex_df['word'][i]
    association=emolex_df['association'][i]

    if word not in word_emotion:
        word_emotion[word]=dict()
    word_emotion[word][emotion]=association

# %%
for i in range(0,len(df)): # Change the loop range to iterate over the length of the DataFrame
    text=df['full_text'][i]
    for j in text.split():
        if j in word_emotion:
            for k in word_emotion[j]:
                emotions[k]+=word_emotion[j][k]
emotions
# Out:
# {'positive': 165,
#  'negative': 111,
#  'surprise': 34,
#  'sadness': 55,
#  'anger': 62,
#  'joy': 47,
#  'trust': 93,
#  'fear': 62,
#  'anticipation': 64,
#  'disgust': 46}

# %%
plt.style.use('fivethirtyeight')
plt.rcParams["figure.figsize"] = [15,5]
plt.bar(list(emotions.keys()),list(emotions.values()),color='red',alpha = 0.6)
plt.xlabel('Emotions')
plt.ylabel('Count')
plt.title('Calculated Emotions Of Users ')
plt.show()

# %%
df1 = df

# %%
df1['sentiment'] = sentimental_score_df['val']

# %%
df1.head()
# Out:
#    conversation_id_str                created_at  favorite_count  \
# 0  1833973370460815785 2024-09-11 20:58:19+00:00             288
# 1  1840195818198052940 2024-09-29 01:04:06+00:00             345
# 2  1836786753765519766 2024-09-19 15:17:42+00:00            4464
# 3  1850662507481792623 2024-10-27 22:15:26+00:00             723
# 4  1847203688097407237 2024-10-18 09:10:53+00:00             494
#
#                                            full_text               id_str  \
# 0  TRUMP 2024 🇺🇸🇺🇸 @LadyConstance8 @NancyMar2022 ...  1833973370460815785
# 1  ⭐️ The 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘴𝘱𝘪𝘳𝘪𝘵 𝘪𝘴 𝙂𝙍𝙀𝘼𝙏! ⭐️ 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘤...  1840195818198052940
# 2  Recent Poll shows Donald Trump WINNING IN A LA...  1836786753765519766
# 3  @realDonaldTrump With Trump in 2024? Here s a ...  1850662617917858188
# 4  NOW more than EVER MAGA 🇺🇸 TRUMP 2024 https://...  1847203688097407237
#
#                                            image_url in_reply_to_screen_name  \
# 0    https://pbs.twimg.com/media/GXOVD0cXYAAl3D_.jpg                     NaN
# 1  https://pbs.twimg.com/amplify_video_thumb/1840...                     NaN
# 2    https://pbs.twimg.com/media/GX2TzpvX0AADuiW.jpg                     NaN
# 3    https://pbs.twimg.com/media/Ga7f13qWcAEgvoP.jpg         realDonaldTrump
# 4    https://pbs.twimg.com/media/GaKV9p7XgAAaeJF.jpg                     NaN
#
#   lang               location  quote_count  reply_count  retweet_count  \
# 0   en                    NaN            6           47            168
# 1   en  The Great Lakes State            4            6            238
# 2   en                India🇮🇳           44         1218            816
# 3   en                    NaN            4           67             97
# 4   en                    NaN            1           25            212
#
#                                            tweet_url          user_id_str  \
# 0  https://x.com/Langer424/status/183397337046081...  1521692036897902592
# 1  https://x.com/1776Diva/status/1840195818198052940  1343367645748473856
# 2  https://x.com/SUBRATA30016572/status/183678675...  1142736007567069184
# 3  https://x.com/TuckerCarlsonHQ/status/185066261...  1755191109574107136
# 4  https://x.com/DameScorpio/status/1847203688097...  1551523351843192834
#
#           username                                    Processed_Tweet  \
# 0        Langer424                                            [trump]
# 1         1776Diva                                                 []
# 2  SUBRATA30016572  [recent, poll, show, donald, trump, win, lands...
# 3  TuckerCarlsonHQ                              [trump, follow, back]
# 4      DameScorpio                            [ever, mag, ##a, trump]
#
#   sentiment
# 0   Neutral
# 1   Neutral
# 2  Positive
# 3   Neutral
# 4   Neutral

# %%
# !pip install pandas

import pandas as pd

# Convert 'created_at' column to datetime if it's not already
df['created_at'] = pd.to_datetime(df['created_at'])

# Extract the day from the 'created_at' column
df1['day'] = df['created_at'].dt.day

df1.head()
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#    conversation_id_str                created_at  favorite_count  \
# 0  1833973370460815785 2024-09-11 20:58:19+00:00             288
# 1  1840195818198052940 2024-09-29 01:04:06+00:00             345
# 2  1836786753765519766 2024-09-19 15:17:42+00:00            4464
# 3  1850662507481792623 2024-10-27 22:15:26+00:00             723
# 4  1847203688097407237 2024-10-18 09:10:53+00:00             494
#
#                                            full_text               id_str  \
# 0  TRUMP 2024 🇺🇸🇺🇸 @LadyConstance8 @NancyMar2022 ...  1833973370460815785
# 1  ⭐️ The 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘴𝘱𝘪𝘳𝘪𝘵 𝘪𝘴 𝙂𝙍𝙀𝘼𝙏! ⭐️ 𝘈𝘮𝘦𝘳𝘪𝘤𝘢𝘯 𝘤...  1840195818198052940
# 2  Recent Poll shows Donald Trump WINNING IN A LA...  1836786753765519766
# 3  @realDonaldTrump With Trump in 2024? Here s a ...  1850662617917858188
# 4  NOW more than EVER MAGA 🇺🇸 TRUMP 2024 https://...  1847203688097407237
#
#                                            image_url in_reply_to_screen_name  \
# 0    https://pbs.twimg.com/media/GXOVD0cXYAAl3D_.jpg                     NaN
# 1  https://pbs.twimg.com/amplify_video_thumb/1840...                     NaN
# 2    https://pbs.twimg.com/media/GX2TzpvX0AADuiW.jpg                     NaN
# 3    https://pbs.twimg.com/media/Ga7f13qWcAEgvoP.jpg         realDonaldTrump
# 4    https://pbs.twimg.com/media/GaKV9p7XgAAaeJF.jpg                     NaN
#
#   lang               location  quote_count  reply_count  retweet_count  \
# 0   en                    NaN            6           47            168
# 1   en  The Great Lakes State            4            6            238
# 2   en                India🇮🇳           44         1218            816
# 3   en                    NaN            4           67             97
# 4   en                    NaN            1           25            212
#
#                                            tweet_url          user_id_str  \
# 0  https://x.com/Langer424/status/183397337046081...  1521692036897902592
# 1  https://x.com/1776Diva/status/1840195818198052940  1343367645748473856
# 2  https://x.com/SUBRATA30016572/status/183678675...  1142736007567069184
# 3  https://x.com/TuckerCarlsonHQ/status/185066261...  1755191109574107136
# 4  https://x.com/DameScorpio/status/1847203688097...  1551523351843192834
#
#           username                                    Processed_Tweet  \
# 0        Langer424                                            [trump]
# 1         1776Diva                                                 []
# 2  SUBRATA30016572  [recent, poll, show, donald, trump, win, lands...
# 3  TuckerCarlsonHQ                              [trump, follow, back]
# 4      DameScorpio                            [ever, mag, ##a, trump]
#
#   sentiment  day
# 0   Neutral   11
# 1   Neutral   29
# 2  Positive   19
# 3   Neutral   27
# 4   Neutral   18

# %%
import pandas as pd
import seaborn as sns

# Assuming df1 contains both 'day' and 'sentiment' columns
# Melt the DataFrame to convert it to long-form
df_melted = pd.melt(df1, id_vars=['day'], value_vars=['sentiment'], var_name='Sentiment', value_name='Values')

# Now use the melted DataFrame for the countplot
sns.countplot(x='day', hue='Values', data=df_melted)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# **Predicting using Machine Learning Model**

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn import model_selection

from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
le = LabelEncoder()

df1['sentiment_1']= le.fit_transform(df1['sentiment'])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Defining the vectorizer
vect = TfidfVectorizer(ngram_range=(1,1), max_features=1500).fit(all_words)

# Transform the vectorizer
X_tfidf = vect.transform(all_words).toarray()

# %%
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(all_words).toarray()
y = df1['sentiment_1']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
# NEGATIVE == 0
# NEUTRAL == 1
# POSITIVE == 2

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size = 0.3, random_state = 0)

# %% [markdown]
# **Decision Tree**

# %%
classifier_DT = DecisionTreeClassifier()
classifier_DT.fit(X_train, y_train)
y_pred_DT = classifier_DT.predict(X_test)

# %%
accuracy_score_DT = accuracy_score(y_test, y_pred_DT)
precision_score_DT = precision_score(y_test, y_pred_DT , average = 'micro')
recall_score_DT = recall_score(y_test, y_pred_DT , average = 'micro')
f1_score_DT = f1_score(y_test, y_pred_DT , average = 'micro')
print("Accuracy Score: " , accuracy_score_DT)
print("Precision Score: " , precision_score_DT)
print("Recall Score: " , recall_score_DT)
print("F1 Score: " , f1_score_DT)
# Out:
# Accuracy Score:  0.5782312925170068
# Precision Score:  0.5782312925170068
# Recall Score:  0.5782312925170068
# F1 Score:  0.5782312925170068

# %%
cm_DT = confusion_matrix(y_test, y_pred_DT)

# %%
df_cm_DT = pd.DataFrame(cm_DT, range(3), range(3))
plt.figure(figsize=(10,6))
categories = ['Negative','Neutral','Positive']
sns.set(font_scale=1.2) # for label size
sns.heatmap(df_cm_DT, annot=True, annot_kws={"size": 18}, xticklabels = categories,
            yticklabels = categories ,fmt="d") # font size
plt.ylim(0, 3)
plt.show()

# %% [markdown]
# **Hyperparameter Tuning for Decision Tree**

# %%
#Getting the parameters of the particular model
classifier_DT.get_params().keys()
# Out:
# dict_keys(['ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'monotonic_cst', 'random_state', 'splitter'])

# %%
classifier_DT_opti = DecisionTreeClassifier()

param_grid = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
model_DT = model_selection.GridSearchCV(estimator=classifier_DT_opti, #GridSearch
                                    param_grid=param_grid,
                                        cv=10)
model_DT.fit(X_train,y_train)
print(model_DT.best_score_) #Gives the best score of the model
print(model_DT.best_estimator_.get_params()) #Gives the best parameters
# Out:
# 0.6205882352941178
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': None, 'splitter': 'best'}

# %%
y_pred_model_DT = model_DT.predict(X_test)

accuracy_score_model_DT = accuracy_score(y_test, y_pred_model_DT)
precision_score_model_DT = precision_score(y_test, y_pred_model_DT , average = 'micro')
recall_score_model_DT = recall_score(y_test, y_pred_model_DT , average = 'micro')
f1_score_model_DT = f1_score(y_test, y_pred_model_DT , average = 'micro')
print("Accuracy Score: " , accuracy_score_model_DT)
print("Precision Score: " , precision_score_model_DT)
print("Recall Score: " , recall_score_model_DT)
print("F1 Score: " , f1_score_model_DT)
# Out:
# Accuracy Score:  0.6326530612244898
# Precision Score:  0.6326530612244898
# Recall Score:  0.6326530612244898
# F1 Score:  0.6326530612244898

# %%
cm_model_DT = confusion_matrix(y_test, y_pred_model_DT)

df_cm_model_DT = pd.DataFrame(cm_model_DT, range(3), range(3))
plt.figure(figsize=(10,6))
categories = ['Negative','Neutral','Positive']
sns.set(font_scale=1.2) # for label size
sns.heatmap(df_cm_model_DT, annot=True, annot_kws={"size": 18}, xticklabels = categories,
            yticklabels = categories ,fmt="d") # font size
plt.ylim(0, 3)
plt.show()

# %% [markdown]
# **Random Forest**

# %%
classifier_RF = RandomForestClassifier()
classifier_RF.fit(X_train, y_train)
y_pred_RF = classifier_RF.predict(X_test)

# %%
accuracy_score_RF = accuracy_score(y_test, y_pred_RF)
precision_score_RF = precision_score(y_test, y_pred_RF , average = 'micro')
recall_score_RF = recall_score(y_test, y_pred_RF, average = 'micro')
f1_score_RF = f1_score(y_test, y_pred_RF, average = 'micro')
print("Accuracy Score: " , accuracy_score_RF)
print("Precision Score: " , precision_score_RF)
print("Recall Score: " , recall_score_RF)
print("F1 Score: " , f1_score_RF)
# Out:
# Accuracy Score:  0.6326530612244898
# Precision Score:  0.6326530612244898
# Recall Score:  0.6326530612244898
# F1 Score:  0.6326530612244898

# %%
cm_RF = confusion_matrix(y_test, y_pred_RF)

df_cm_RF = pd.DataFrame(cm_RF, range(3), range(3))
categories = ['Negative','Neutral','Positive']
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2) # for label size
sns.heatmap(df_cm_RF, annot=True, annot_kws={"size": 18}, xticklabels = categories,
            yticklabels = categories,fmt="d") # font size
plt.ylim(0, 3)
plt.show()

# %% [markdown]
# **Hyperparameter tuning for Random Forest**

# %%
#Getting the parameters of the particular model
classifier_RF.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'monotonic_cst', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
classifier_RF_opti = RandomForestClassifier()
param_grid = {"n_estimators": np.arange(100,1500,100), #Selecting the parameters
               "max_depth": np.arange(1,20),
               "criterion": ["gini","entropy"],
              }

# %%
classifier_model_RF = model_selection.RandomizedSearchCV(estimator=classifier_RF_opti, #RandomizedSearch
                                    param_distributions=param_grid,
                                    n_iter=10,
                                    scoring='accuracy',
                                    verbose=10,
                                    n_jobs=1,
                                    cv=5)

classifier_model_RF.fit(X_train,y_train)
print(classifier_model_RF.best_score_) #Gives the best score of the model
print(classifier_model_RF.best_estimator_.get_params()) #Gives the best parameters of the model
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START criterion=gini, max_depth=7, n_estimators=600..............
# [CV 1/5; 1/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.478 total time=   2.5s
# [CV 2/5; 1/10] START criterion=gini, max_depth=7, n_estimators=600..............
# [CV 2/5; 1/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.536 total time=   2.2s
# [CV 3/5; 1/10] START criterion=gini, max_depth=7, n_estimators=600..............
# [CV 3/5; 1/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.536 total time=   2.2s
# [CV 4/5; 1/10] START criterion=gini, max_depth=7, n_estimators=600..............
# [CV 4/5; 1/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.544 total time=   2.6s
# [CV 5/5; 1/10] START criterion=gini, max_depth=7, n_estimators=600..............
# [CV 5/5; 1/10] END criterion=gini, max_depth=7, n_estimators=600;, score=0.500 total time=   3.8s
# [CV 1/5; 2/10] START criterion=gini, max_depth=19, n_estimators=600.............
# [CV 1/5; 2/10] END criterion=gini, max_depth=19, n_estimators=600;, score=0.522 total time=   3.6s
# [CV 2/5; 2/10] START criterion=gini, max_depth=19, n_estimators=600.............
# [CV 2/5; 2/10] END criterion=gini, max_depth=19, n_estimators=600;, score=0.565 total time=   3.6s
# [CV 3/5; 2/10] START criterion=gini, max_depth=19, n_estimators=600.............
# [CV 3/5; 2/10] END criterion=gini, max_depth=19, n_estimators=600;, score=0.652 total time=   4.0s
# [CV 4/5; 2/10] START criterion=gini, max_depth=19, n_estimators=600.............
# [CV 4/5; 2/10] END criterion=gini, max_depth=19, n_estimators=600;, score=0.662 total time=   5.0s
# [CV 5/5; 2/10] START criterion=gini, max_depth=19, n_estimators=600.............
# [CV 5/5; 2/10] END criterion=gini, max_depth=19, n_estimators=600;, score=0.544 total time=   3.0s
# [CV 1/5; 3/10] START criterion=entropy, max_depth=10, n_estimators=500..........
# [CV 1/5; 3/10] END criterion=entropy, max_depth=10, n_estimators=500;, score=0.507 total time=   1.0s
# [CV 2/5; 3/10] START criterion=entropy, max_depth=10, n_estimators=500..........
# [CV 2/5; 3/10] END criterion=entropy, max_depth=10, n_estimators=500;, score=0.565 total time=   1.0s
# [CV 3/5; 3/10] START criterion=entropy, max_depth=10, n_estimators=500..........
# [CV 3/5; 3/10] END criterion=entropy, max_depth=10, n_estimators=500;, score=0.594 total time=   1.0s
# [CV 4/5; 3/10] START criterion=entropy, max_depth=10, n_estimators=500..........
# [CV 4/5; 3/10] END criterion=entropy, max_depth=10, n_estimators=500;, score=0.559 total time=   1.0s
# [CV 5/5; 3/10] START criterion=entropy, max_depth=10, n_estimators=500..........
# [CV 5/5; 3/10] END criterion=entropy, max_depth=10, n_estimators=500;, score=0.529 total time=   1.0s
# [CV 1/5; 4/10] START criterion=gini, max_depth=5, n_estimators=400..............
# [CV 1/5; 4/10] END criterion=gini, max_depth=5, n_estimators=400;, score=0.536 total time=   1.2s
# [CV 2/5; 4/10] START criterion=gini, max_depth=5, n_estimators=400..............
# [CV 2/5; 4/10] END criterion=gini, max_depth=5, n_estimators=400;, score=0.493 total time=   1.2s
# [CV 3/5; 4/10] START criterion=gini, max_depth=5, n_estimators=400..............
# [CV 3/5; 4/10] END criterion=gini, max_depth=5, n_estimators=400;, score=0.522 total time=   1.2s
# [CV 4/5; 4/10] START criterion=gini, max_depth=5, n_estimators=400..............
# [CV 4/5; 4/10] END criterion=gini, max_depth=5, n_estimators=400;, score=0.515 total time=   0.8s
# [CV 5/5; 4/10] START criterion=gini, max_depth=5, n_estimators=400..............
# [CV 5/5; 4/10] END criterion=gini, max_depth=5, n_estimators=400;, score=0.515 total time=   0.7s
# [CV 1/5; 5/10] START criterion=gini, max_depth=6, n_estimators=1100.............
# [CV 1/5; 5/10] END criterion=gini, max_depth=6, n_estimators=1100;, score=0.522 total time=   1.9s
# [CV 2/5; 5/10] START criterion=gini, max_depth=6, n_estimators=1100.............
# [CV 2/5; 5/10] END criterion=gini, max_depth=6, n_estimators=1100;, score=0.507 total time=   1.9s
# [CV 3/5; 5/10] START criterion=gini, max_depth=6, n_estimators=1100.............
# [CV 3/5; 5/10] END criterion=gini, max_depth=6, n_estimators=1100;, score=0.522 total time=   1.9s
# [CV 4/5; 5/10] START criterion=gini, max_depth=6, n_estimators=1100.............
# [CV 4/5; 5/10] END criterion=gini, max_depth=6, n_estimators=1100;, score=0.515 total time=   2.0s
# [CV 5/5; 5/10] START criterion=gini, max_depth=6, n_estimators=1100.............
# [CV 5/5; 5/10] END criterion=gini, max_depth=6, n_estimators=1100;, score=0.500 total time=   3.0s
# [CV 1/5; 6/10] START criterion=gini, max_depth=15, n_estimators=900.............
# [CV 1/5; 6/10] END criterion=gini, max_depth=15, n_estimators=900;, score=0.536 total time=   4.8s
# [CV 2/5; 6/10] START criterion=gini, max_depth=15, n_estimators=900.............
# [CV 2/5; 6/10] END criterion=gini, max_depth=15, n_estimators=900;, score=0.536 total time=   6.0s
# [CV 3/5; 6/10] START criterion=gini, max_depth=15, n_estimators=900.............
# [CV 3/5; 6/10] END criterion=gini, max_depth=15, n_estimators=900;, score=0.652 total time=  10.2s
# [CV 4/5; 6/10] START criterion=gini, max_depth=15, n_estimators=900.............
# [CV 4/5; 6/10] END criterion=gini, max_depth=15, n_estimators=900;, score=0.603 total time=   8.2s
# [CV 5/5; 6/10] START criterion=gini, max_depth=15, n_estimators=900.............
# [CV 5/5; 6/10] END criterion=gini, max_depth=15, n_estimators=900;, score=0.544 total time=   5.5s
# [CV 1/5; 7/10] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 1/5; 7/10] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.565 total time=   3.8s
# [CV 2/5; 7/10] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 2/5; 7/10] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.565 total time=   2.2s
# [CV 3/5; 7/10] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 3/5; 7/10] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.667 total time=   3.7s
# [CV 4/5; 7/10] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 4/5; 7/10] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.691 total time=   2.3s
# [CV 5/5; 7/10] START criterion=entropy, max_depth=18, n_estimators=1000.........
# [CV 5/5; 7/10] END criterion=entropy, max_depth=18, n_estimators=1000;, score=0.529 total time=   2.2s
# [CV 1/5; 8/10] START criterion=gini, max_depth=10, n_estimators=300.............
# [CV 1/5; 8/10] END criterion=gini, max_depth=10, n_estimators=300;, score=0.522 total time=   0.6s
# [CV 2/5; 8/10] START criterion=gini, max_depth=10, n_estimators=300.............
# [CV 2/5; 8/10] END criterion=gini, max_depth=10, n_estimators=300;, score=0.551 total time=   0.6s
# [CV 3/5; 8/10] START criterion=gini, max_depth=10, n_estimators=300.............
# [CV 3/5; 8/10] END criterion=gini, max_depth=10, n_estimators=300;, score=0.565 total time=   0.6s
# [CV 4/5; 8/10] START criterion=gini, max_depth=10, n_estimators=300.............
# [CV 4/5; 8/10] END criterion=gini, max_depth=10, n_estimators=300;, score=0.574 total time=   0.6s
# [CV 5/5; 8/10] START criterion=gini, max_depth=10, n_estimators=300.............
# [CV 5/5; 8/10] END criterion=gini, max_depth=10, n_estimators=300;, score=0.515 total time=   0.6s
# [CV 1/5; 9/10] START criterion=gini, max_depth=18, n_estimators=1100............
# [CV 1/5; 9/10] END criterion=gini, max_depth=18, n_estimators=1100;, score=0.551 total time=   2.4s
# [CV 2/5; 9/10] START criterion=gini, max_depth=18, n_estimators=1100............
# [CV 2/5; 9/10] END criterion=gini, max_depth=18, n_estimators=1100;, score=0.536 total time=   3.9s
# [CV 3/5; 9/10] START criterion=gini, max_depth=18, n_estimators=1100............
# [CV 3/5; 9/10] END criterion=gini, max_depth=18, n_estimators=1100;, score=0.638 total time=   2.4s
# [CV 4/5; 9/10] START criterion=gini, max_depth=18, n_estimators=1100............
# [CV 4/5; 9/10] END criterion=gini, max_depth=18, n_estimators=1100;, score=0.647 total time=   2.3s
# [CV 5/5; 9/10] START criterion=gini, max_depth=18, n_estimators=1100............
# [CV 5/5; 9/10] END criterion=gini, max_depth=18, n_estimators=1100;, score=0.544 total time=   2.4s
# [CV 1/5; 10/10] START criterion=entropy, max_depth=16, n_estimators=1000........
# [CV 1/5; 10/10] END criterion=entropy, max_depth=16, n_estimators=1000;, score=0.536 total time=   2.2s
# [CV 2/5; 10/10] START criterion=entropy, max_depth=16, n_estimators=1000........
# [CV 2/5; 10/10] END criterion=entropy, max_depth=16, n_estimators=1000;, score=0.551 total time=   4.4s
# [CV 3/5; 10/10] START criterion=entropy, max_depth=16, n_estimators=1000........
# [CV 3/5; 10/10] END criterion=entropy, max_depth=16, n_estimators=1000;, score=0.609 total time=   2.2s
# [CV 4/5; 10/10] START criterion=entropy, max_depth=16, n_estimators=1000........
# [CV 4/5; 10/10] END criterion=entropy, max_depth=16, n_estimators=1000;, score=0.632 total time=   2.2s
# [CV 5/5; 10/10] START criterion=entropy, max_depth=16, n_estimators=1000........
# [CV 5/5; 10/10] END criterion=entropy, max_depth=16, n_estimators=1000;, score=0.544 total time=   2.2s
# 0.603537936913896
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 18, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 1000, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
y_pred_model_RF = classifier_model_RF.predict(X_test)

accuracy_score_model_RF = accuracy_score(y_test, y_pred_model_RF)
precision_score_model_RF = precision_score(y_test, y_pred_model_RF , average = 'micro')
recall_score_model_RF = recall_score(y_test, y_pred_model_RF , average = 'micro')
f1_score_model_RF = f1_score(y_test, y_pred_model_RF , average = 'micro')
print("Accuracy Score: " , accuracy_score_model_RF)
print("Precision Score: " , precision_score_model_RF)
print("Recall Score: " , recall_score_model_RF)
print("F1 Score: " , f1_score_model_RF)
# Out:
# Accuracy Score:  0.6054421768707483
# Precision Score:  0.6054421768707483
# Recall Score:  0.6054421768707483
# F1 Score:  0.6054421768707483

# %%
cm_model_RF = confusion_matrix(y_test, y_pred_model_RF)

df_cm_model_RF = pd.DataFrame(cm_model_RF, range(3), range(3))
plt.figure(figsize=(10,6))
categories = ['Negative','Neutral','Positive']
sns.set(font_scale=1.2) # for label size
sns.heatmap(df_cm_model_RF, annot=True, annot_kws={"size": 18}, xticklabels = categories,
            yticklabels = categories ,fmt="d") # font size
plt.ylim(0, 3)
plt.show()

# %% [markdown]
# **Model Comparison**

# %%
Accuracy = [accuracy_score_RF, accuracy_score_DT]
Methods = ['Random_Forest', 'Decision_Trees']
Accuracy_pos = np.arange(len(Methods))
plt.bar(Accuracy_pos, Accuracy)
plt.xticks(Accuracy_pos, Methods)
plt.title('Comparing Accuracy Score')
plt.show()

# %%
Precision = [precision_score_RF, precision_score_DT]
Methods = ['Random_Forest', 'Decision_Trees']
Precision_pos = np.arange(len(Methods))
plt.bar(Precision_pos, Precision)
plt.xticks(Precision_pos, Methods)
plt.title('Comparing Precision Score')
plt.show()

# %%
Recall = [recall_score_RF, recall_score_DT]
Methods = ['Random_Forest', 'Decision_Trees']
Recall_pos = np.arange(len(Methods))
plt.bar(Recall_pos, Recall)
plt.xticks(Recall_pos, Methods)
plt.title('Comparing Recall Score')
plt.show()

# %%
F1 = [f1_score_RF,f1_score_DT]
Methods = ['Random_Forest', 'Decision_Trees']
F1_pos = np.arange(len(Methods))
plt.bar(F1_pos, F1)
plt.xticks(F1_pos, Methods)
plt.title('Comparing F1 Score')
plt.show()

# %%
from sklearn.metrics import roc_auc_score # Import the roc_auc_score function

# Specify 'multi_class' as 'ovr' or 'ovo'
roc_auc = roc_auc_score(y_test, classifier_RF.predict_proba(X_test), multi_class='ovr')  # or multi_class='ovo'
#If you use 'ovr', it calculates the ROC AUC for each class against the rest and then averages the scores.
#If you use 'ovo', it calculates the ROC AUC for each pair of classes and then averages the scores.

# %%
print(f"ROC-AUC: {roc_auc:.2f}")
# Out:
# ROC-AUC: 0.77

# %%
roc_auc = roc_auc_score(y_test, classifier_DT.predict_proba(X_test), multi_class='ovr')  # or multi_class='ovo'

# %%
print(f"ROC-AUC: {roc_auc:.2f}")
# Out:
# ROC-AUC: 0.64

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np

# Get predicted probabilities for all classes
y_prob_DT = model_DT.predict_proba(X_test)
y_prob_RF = classifier_model_RF.predict_proba(X_test)

# Number of classes
n_classes = y_prob_DT.shape[1]

# Plotting ROC curves for each class
plt.figure(figsize=(10, 7))

for i in range(n_classes):
    # Compute ROC curve and AUC for Decision Tree for class i
    fpr_DT, tpr_DT, _ = roc_curve(y_test, y_prob_DT[:, i], pos_label=i)
    roc_auc_DT = auc(fpr_DT, tpr_DT)

    # Compute ROC curve and AUC for Random Forest for class i
    fpr_RF, tpr_RF, _ = roc_curve(y_test, y_prob_RF[:, i], pos_label=i)
    roc_auc_RF = auc(fpr_RF, tpr_RF)

    # Plot ROC curves for class i
    plt.plot(fpr_DT, tpr_DT, lw=2, label=f'Decision Tree (Class {i}, AUC = {roc_auc_DT:.2f})')
    plt.plot(fpr_RF, tpr_RF, lw=2, label=f'Random Forest (Class {i}, AUC = {roc_auc_RF:.2f})')

# Plot the baseline
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')

# Add labels and title
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Tree and Random Forest (Multi-Class)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 1. Assuming 'df1' has 'created_at' and 'sentiment' columns
df1['created_at'] = pd.to_datetime(df1['created_at'])  # Convert to datetime if needed
df1['date'] = df1['created_at'].dt.date  # Extract date

# 2. Group by date and count sentiments
sentiment_over_time = df1.groupby(['date', 'sentiment'])['sentiment'].count().reset_index(name='count')

# 3. Create the plot using Seaborn
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
ax = sns.lineplot(x='date', y='count', hue='sentiment', data=sentiment_over_time)

# 4. Customize the plot
ax.set_title('Sentiment Over Time(Donald Trump)')
ax.set_xlabel('Date')
ax.set_ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels if needed
plt.tight_layout()

# 5. Show the plot
plt.show()
